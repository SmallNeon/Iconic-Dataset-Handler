# %% [markdown]
# # System Statues Check

# %%
import torch
print(torch.__version__)
import psutil

def print_system_usage():
    # 获取 CPU 信息
    cpu_count = psutil.cpu_count(logical=True)
    cpu_usage = psutil.cpu_percent()
    
    # 获取内存信息
    memory_info = psutil.virtual_memory()
    total_memory_gb = memory_info.total / 1024 ** 3
    used_memory_gb = memory_info.used / 1024 ** 3
    memory_usage_percent = memory_info.percent

    # 获取 GPU 信息
    if torch.cuda.is_available():
        gpu_name = torch.cuda.get_device_name(0)
        cuda_capability = torch.cuda.get_device_capability(0)
        gpu_memory_total = torch.cuda.get_device_properties(0).total_memory / 1024 ** 3
        gpu_memory_used = torch.cuda.memory_allocated(0) / 1024 ** 3
        gpu_memory_usage_percent = (gpu_memory_used / gpu_memory_total) * 100
        gpu_info = f"{gpu_name}, CUDA {cuda_capability[0]}.{cuda_capability[1]}, {gpu_memory_used:.2f}/{gpu_memory_total:.2f} GB ({gpu_memory_usage_percent:.1f}%)"
    else:
        gpu_info = "No GPU available"

    # 打印系统信息在一行
    print(f"CPU: {cpu_count} cores, {cpu_usage}% | RAM: {used_memory_gb:.2f}/{total_memory_gb:.2f} GB ({memory_usage_percent}%) | GPU: {gpu_info}")

# 调用函数
print_system_usage()
# Out:
# 2.3.0+cu121
# CPU: 32 cores, 3.7% | RAM: 8.87/125.48 GB (9.0%) | GPU: NVIDIA RTX A5000, CUDA 8.6, 0.00/23.68 GB (0.0%)

# %% [markdown]
# # Database

# %%
import os
import sqlite3

# 定义数据库路径和数据文件夹路径
db_path = 'patient_data.db'
full_dataset_path = '/media/molloi-lab-linux2/HD-88/ICONIC CCTAS'  # 替换为实际路径
subset_path = '/home/molloi-lab-linux2/Desktop/ZQY/shant2'       # 替换为实际路径

# 检查数据库是否已存在
if os.path.exists(db_path):
    print(f"数据库 '{db_path}' 已存在。")
    
    # 连接到现有数据库并打印基础信息
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # 检查表是否存在以及基础信息
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='patient_data'")
    table_exists = cursor.fetchone()
    
    if table_exists:
        print("数据库中已包含表 'patient_data'。")
        
        # 获取表结构信息
        cursor.execute("PRAGMA table_info(patient_data)")
        columns = cursor.fetchall()
        print("表结构:")
        for column in columns:
            print(f" - {column[1]} ({column[2]})")
        
        # 打印表中已有的记录数
        cursor.execute("SELECT COUNT(*) FROM patient_data")
        record_count = cursor.fetchone()[0]
        print(f"表 'patient_data' 中已有记录数: {record_count}")
    else:
        print("数据库存在，但未找到表 'patient_data'。")
    
    # 关闭数据库连接
    conn.close()
else:
    # 如果数据库不存在，创建一个新的数据库和表结构
    print(f"数据库 '{db_path}' 不存在，正在创建新数据库并初始化数据...")
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # 创建表结构，新增字段
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS patient_data (
            -- 文件属性
            id INTEGER PRIMARY KEY AUTOINCREMENT,     -- 每条记录的唯一标识符，自增主键
            patient_id TEXT,                          -- 患者 ID，从文件夹名获取，用于识别患者
            nii_path TEXT,                            -- .nii 文件的路径，用于定位具体文件
                   
            -- 标记结果
            contrast_type TEXT,                       -- 对比类型 ("Contrast", "Uncontrast", "Mid")，初始时留空
            contrast_level REAL,                      -- 对比度等级 (0-1)，表示对比强度，初始时留空
            usable_slices TEXT,                       -- 可用于训练的切片编号，以逗号分隔的字符串形式存储
            usable_for_training TEXT,                 -- 是否用于训练 ("Yes", "No", "Partial")，初始时留空
            in_subset TEXT,                           -- 标记文件是否在子数据集 (shant2) 中 ("Yes" 或 "No")
            
            -- 标记过程用字段
            is_discarded TEXT,                        -- 是否弃用数据 ("Yes" 或 "No")，默认值为 "No"
            manual_contrast_type TEXT,                -- 手动分类的对比类型 ("contrast", "non contrast", "mid")，用户手动指定
            brightness_contrast_type TEXT,            -- 基于亮度值的对比分类 ("contrast", "non contrast", "mid")，用于记录自动分类结果
            brightness_max REAL,                      -- 亮度最大值，记录图像数据中的最大亮度值
            brightness_min REAL,                      -- 亮度最小值，记录图像数据中的最小亮度值
            brightness_avg REAL                       -- 亮度平均值，记录图像数据中的平均亮度值
        )
    ''')
    conn.commit()
    
    # 遍历 shant 文件夹，初始化数据库条目
    for patient_folder in os.listdir(full_dataset_path):
        patient_path = os.path.join(full_dataset_path, patient_folder)
        
        if os.path.isdir(patient_path):
            patient_id = patient_folder  # 用文件夹名作为患者 ID
            
            for nii_file in os.listdir(patient_path):
                if nii_file.endswith(".nii"):
                    nii_path = os.path.join(patient_path, nii_file)
                    
                    # 检查该 .nii 文件是否也在 shant2 子数据集中
                    relative_nii_path = os.path.relpath(nii_path, full_dataset_path)
                    in_subset = "Yes" if os.path.exists(os.path.join(subset_path, relative_nii_path)) else "No"
                    
                    # 插入新的条目到数据库，初始属性值留空或设为默认
                    cursor.execute('''
                        INSERT INTO patient_data (
                            patient_id, nii_path, contrast_type, contrast_level, usable_slices,
                            usable_for_training, in_subset, is_discarded, manual_contrast_type, 
                            brightness_contrast_type, brightness_max, brightness_min, brightness_avg
                        )
                        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
                    ''', (patient_id, nii_path, None, None, None, None, in_subset, "No", None, None, None, None, None))
    
    conn.commit()
    print("新数据库和表 'patient_data' 已创建，并已从 'shant' 文件夹初始化数据。")
    
    # 关闭数据库连接
    conn.close()
# Out:
# 数据库 'patient_data.db' 已存在。
# 数据库存在，但未找到表 'patient_data'。

# %% [markdown]
# # Select Training Data

# %% [markdown]
# ## Brightness Classification

# %%
import os
import sqlite3
import SimpleITK as sitk
import numpy as np
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock


# 连接到数据库
conn = sqlite3.connect(db_path, check_same_thread=False)  # 多线程模式下需要设置 check_same_thread=False
cursor = conn.cursor()

# 获取数据库中的所有 .nii 文件路径
cursor.execute("SELECT id, patient_id, nii_path FROM patient_data")
records = cursor.fetchall()
total_files = len(records)  # 总文件数

# 锁，用于线程间同步数据库写入
lock = Lock()

def process_file(record):
    """处理每个 .nii 文件，计算亮度信息并更新数据库"""
    record_id, patient_id, nii_path = record
    if os.path.exists(nii_path):
        try:
            # 加载 .nii 文件
            img = sitk.ReadImage(nii_path)
            data = sitk.GetArrayFromImage(img)  # 转换为 NumPy 数组
            
            # 计算亮度统计信息
            brightness_max = np.max(data)
            brightness_min = np.min(data)
            brightness_avg = np.mean(data)
            
            # 更新数据库中的亮度信息（使用锁来确保数据库操作的线程安全）
            with lock:
                cursor.execute('''
                    UPDATE patient_data
                    SET brightness_max = ?, brightness_min = ?, brightness_avg = ?
                    WHERE id = ?
                ''', (brightness_max, brightness_min, brightness_avg, record_id))
                conn.commit()
            
            return f"已更新亮度信息: {patient_id} - {nii_path}"
        
        except Exception as e:
            return f"处理文件 {nii_path} 时出错: {e}"
    else:
        return f"文件不存在: {nii_path}"

# 处理进度显示
def show_progress(futures):
    completed = 0
    for future in as_completed(futures):
        print(future.result())  # 输出每个任务的结果
        completed += 1
        progress = (completed / total_files) * 100
        print(f"进度: {progress:.2f}% ({completed}/{total_files})")

# 使用 ThreadPoolExecutor 进行多线程处理
with ThreadPoolExecutor(max_workers=5) as executor:  # 设置线程数量，建议根据 CPU 核心数选择适当数量
    futures = [executor.submit(process_file, record) for record in records]
    show_progress(futures)

# 关闭数据库连接
conn.close()
print("所有亮度信息已更新。")
# Out:
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/0.nii
# 进度: 0.03% (1/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/12.nii
# 进度: 0.06% (2/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/6.nii
# 进度: 0.09% (3/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/3.nii
# 进度: 0.12% (4/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/2.nii
# 进度: 0.15% (5/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/10.nii
# 进度: 0.18% (6/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/7.nii
# 进度: 0.21% (7/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/14.nii
# 进度: 0.24% (8/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/13.nii
# 进度: 0.27% (9/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/5.nii
# 进度: 0.30% (10/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/8.nii
# 进度: 0.33% (11/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/9.nii
# 进度: 0.36% (12/3350)
# 已更新亮度信息: Confirm_18437 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18437/3.nii
# 进度: 0.39% (13/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/11.nii
# 进度: 0.42% (14/3350)
# 已更新亮度信息: Confirm_18437 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18437/2.nii
# 进度: 0.45% (15/3350)
# 已更新亮度信息: Confirm_18437 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18437/4.nii
# 进度: 0.48% (16/3350)
# 已更新亮度信息: Confirm_18437 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18437/0.nii
# 进度: 0.51% (17/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/1.nii
# 进度: 0.54% (18/3350)
# 已更新亮度信息: Confirm_34206 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/6.nii
# 进度: 0.57% (19/3350)
# 已更新亮度信息: Confirm_34206 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/3.nii
# 进度: 0.60% (20/3350)
# 已更新亮度信息: Confirm_34206 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/5.nii
# 进度: 0.63% (21/3350)
# 已更新亮度信息: Confirm_34206 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/2.nii
# 进度: 0.66% (22/3350)
# 已更新亮度信息: Confirm_34206 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/4.nii
# 进度: 0.69% (23/3350)
# 已更新亮度信息: Confirm_18437 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18437/1.nii
# 进度: 0.72% (24/3350)
# 已更新亮度信息: Confirm_7759 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/4.nii
# 进度: 0.75% (25/3350)
# 已更新亮度信息: Confirm_34206 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/0.nii
# 进度: 0.78% (26/3350)
# 已更新亮度信息: Confirm_33494 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33494/0.nii
# 进度: 0.81% (27/3350)
# 已更新亮度信息: Confirm_33494 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33494/6.nii
# 进度: 0.84% (28/3350)
# 已更新亮度信息: Confirm_33494 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33494/5.nii
# 进度: 0.87% (29/3350)
# 已更新亮度信息: Confirm_33494 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33494
3350)
# 已更新亮度信息: Confirm_11853 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11853/9.nii
# 进度: 5.88% (197/3350)
# 已更新亮度信息: Confirm_33601 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33601/3.nii
# 进度: 5.91% (198/3350)
# 已更新亮度信息: Confirm_33601 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33601/0.nii
# 进度: 5.94% (199/3350)
# 已更新亮度信息: Confirm_33601 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33601/2.nii
# 进度: 5.97% (200/3350)
# 已更新亮度信息: Confirm_33601 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33601/1.nii
# 进度: 6.00% (201/3350)
# 已更新亮度信息: Confirm_33601 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33601/4.nii
# 进度: 6.03% (202/3350)
# 已更新亮度信息: Confirm_11853 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11853/11.nii
# 进度: 6.06% (203/3350)
# 已更新亮度信息: Confirm_11853 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11853/4.nii
# 进度: 6.09% (204/3350)
# 已更新亮度信息: Confirm_11853 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11853/1.nii
# 进度: 6.12% (205/3350)
# 已更新亮度信息: Confirm_856 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/0.nii
# 进度: 6.15% (206/3350)
# 已更新亮度信息: Confirm_856 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/3.nii
# 进度: 6.18% (207/3350)
# 已更新亮度信息: Confirm_856 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/6.nii
# 进度: 6.21% (208/3350)
# 已更新亮度信息: Confirm_856 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/2.nii
# 进度: 6.24% (209/3350)
# 已更新亮度信息: Confirm_856 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/7.nii
# 进度: 6.27% (210/3350)
# 已更新亮度信息: Confirm_856 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/5.nii
# 进度: 6.30% (211/3350)
# 已更新亮度信息: Confirm_856 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/8.nii
# 进度: 6.33% (212/3350)
# 已更新亮度信息: Confirm_18790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18790/3.nii
# 进度: 6.36% (213/3350)
# 已更新亮度信息: Confirm_18790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18790/0.nii
# 进度: 6.39% (214/3350)
# 已更新亮度信息: Confirm_856 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/9.nii
# 进度: 6.42% (215/3350)
# 已更新亮度信息: Confirm_856 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/1.nii
# 进度: 6.45% (216/3350)
# 已更新亮度信息: Confirm_18790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18790/4.nii
# 进度: 6.48% (217/3350)
# 已更新亮度信息: Confirm_856 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/4.nii
# 进度: 6.51% (218/3350)
# 已更新亮度信息: Confirm_20426 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20426/0.nii
# 进度: 6.54% (219/3350)
# 已更新亮度信息: Confirm_18790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18790/2.nii
# 进度: 6.57% (220/3350)
# 已更新亮度信息: Confirm_18790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18790/1.nii
# 进度: 6.60% (221/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/6.nii
# 进度: 6.63% (222/3350)
# 已更新亮度信息: Confirm_20426 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20426/2.nii
# 进度: 6.66% (223/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/15.nii
# 进度: 6.69% (224/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/3.nii
# 进度: 6.72% (225/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/2.nii
# 进度: 6.75% (226/3350)
# 已更新亮度信息: Confirm_20426 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20426/1.nii
# 进度: 6.78% (227/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/10.nii
# 进度: 6.81% (228/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/0.nii
# 进度: 6.84% (229/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/5.nii
# 进度: 6.87% (230/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/7.nii
# 进度: 6.90% (231/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/9.nii
# 进度: 6.93% (232/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/8.nii
# 进度: 6.96% (233/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/1.nii
# 进度: 6.99% (234/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/4.nii
# 进度: 7.01% (235/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/14.nii
# 进度: 7.04% (236/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/12.nii
# 进度: 7.07% (237/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/13.nii
# 进度: 7.10% (238/3350)
# 已更新亮度信息: Confirm_25282 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/11.nii
# 进度: 7.13% (239/3350)
# 已更新亮度信息: Confirm_35666 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_35666/0.nii
# 进度: 7.16% (240/3350)
# 已更新亮度信息: Confirm_35666 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_
3350)
# 已更新亮度信息: Confirm_14874 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/11.nii
# 进度: 9.85% (330/3350)
# 已更新亮度信息: Confirm_14874 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/4.nii
# 进度: 9.88% (331/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/3.nii
# 进度: 9.91% (332/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/6.nii
# 进度: 9.94% (333/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/12.nii
# 进度: 9.97% (334/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/2.nii
# 进度: 10.00% (335/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/7.nii
# 进度: 10.03% (336/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/10.nii
# 进度: 10.06% (337/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/8.nii
# 进度: 10.09% (338/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/5.nii
# 进度: 10.12% (339/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/9.nii
# 进度: 10.15% (340/3350)
# 已更新亮度信息: Confirm_32186 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/3.nii
# 进度: 10.18% (341/3350)
# 已更新亮度信息: Confirm_32186 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/0.nii
# 进度: 10.21% (342/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/11.nii
# 进度: 10.24% (343/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/1.nii
# 进度: 10.27% (344/3350)
# 已更新亮度信息: Confirm_32186 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/6.nii
# 进度: 10.30% (345/3350)
# 已更新亮度信息: Confirm_32186 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/5.nii
# 进度: 10.33% (346/3350)
# 已更新亮度信息: Confirm_32186 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/4.nii
# 进度: 10.36% (347/3350)
# 已更新亮度信息: Confirm_53976 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53976/2.nii
# 进度: 10.39% (348/3350)
# 已更新亮度信息: Confirm_53976 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53976/1.nii
# 进度: 10.42% (349/3350)
# 已更新亮度信息: Confirm_16130 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/4.nii
# 进度: 10.45% (350/3350)
# 已更新亮度信息: Confirm_52554 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_52554/0.nii
# 进度: 10.48% (351/3350)
# 已更新亮度信息: Confirm_52554 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_52554/2.nii
# 进度: 10.51% (352/3350)
# 已更新亮度信息: Confirm_32186 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/2.nii
# 进度: 10.54% (353/3350)
# 已更新亮度信息: Confirm_32186 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/1.nii
# 进度: 10.57% (354/3350)
# 已更新亮度信息: Confirm_52554 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_52554/1.nii
# 进度: 10.60% (355/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/6.nii
# 进度: 10.63% (356/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/3.nii
# 进度: 10.66% (357/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/12.nii
# 进度: 10.69% (358/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/0.nii
# 进度: 10.72% (359/3350)
# 已更新亮度信息: Confirm_53976 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53976/0.nii
# 进度: 10.75% (360/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/7.nii
# 进度: 10.78% (361/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/10.nii
# 进度: 10.81% (362/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/8.nii
# 进度: 10.84% (363/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/2.nii
# 进度: 10.87% (364/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/5.nii
# 进度: 10.90% (365/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/9.nii
# 进度: 10.93% (366/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/3.nii
# 进度: 10.96% (367/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/11.nii
# 进度: 10.99% (368/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/4.nii
# 进度: 11.01% (369/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/6.nii
# 进度: 11.04% (370/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/0.nii
# 进度: 11.07% (371/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/15.nii
# 进度: 11.10% (372/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/2.nii
# 进度: 11.13% (373/3350)
# 已更新亮度信息: Confirm_14315 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14315/1.nii
# 进度: 11.16% (374/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/17.nii
# 进度: 11.19% (375/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/12.nii
# 进度: 11.22% (376/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/16.nii
# 进度: 11.25% (377/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/7.nii
# 进度: 11.28% (378/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/10.nii
# 进度: 11.31% (379/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/13.nii
# 进度: 11.34% (380/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/8.nii
# 进度: 11.37% (381/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/1.nii
# 进度: 11.40% (382/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/5.nii
# 进度: 11.43% (383/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/9.nii
# 进度: 11.46% (384/3350)
# 已更新亮度信息: Confirm_34790 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/14.nii
# 进度: 11.49% (385/3350)
# 已更新亮度信息: Confirm_2652 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm
- /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31218/1.nii
# 进度: 99.64% (3338/3350)
# 已更新亮度信息: Confirm_31222 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/6.nii
# 进度: 99.67% (3339/3350)
# 已更新亮度信息: Confirm_31222 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/5.nii
# 进度: 99.70% (3340/3350)
# 已更新亮度信息: Confirm_31222 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/4.nii
# 进度: 99.73% (3341/3350)
# 已更新亮度信息: Confirm_31222 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/2.nii
# 进度: 99.76% (3342/3350)
# 已更新亮度信息: Confirm_31222 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/0.nii
# 进度: 99.79% (3343/3350)
# 已更新亮度信息: Confirm_31222 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/1.nii
# 进度: 99.82% (3344/3350)
# 已更新亮度信息: Confirm_36496 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_36496/0.nii
# 进度: 99.85% (3345/3350)
# 已更新亮度信息: Confirm_36496 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_36496/3.nii
# 进度: 99.88% (3346/3350)
# 已更新亮度信息: Confirm_36496 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_36496/2.nii
# 进度: 99.91% (3347/3350)
# 已更新亮度信息: Confirm_36496 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_36496/5.nii
# 进度: 99.94% (3348/3350)
# 已更新亮度信息: Confirm_36496 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_36496/1.nii
# 进度: 99.97% (3349/3350)
# 已更新亮度信息: Confirm_36496 - /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_36496/4.nii
# 进度: 100.00% (3350/3350)
# 所有亮度信息已更新。

# %% [markdown]
# # Train Model

# %%
import os
import sqlite3
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import SimpleITK as sitk
import numpy as np
from sklearn.cluster import KMeans
from torch.nn.functional import interpolate
from tqdm import tqdm

# 设置设备为 GPU（如果可用）
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)



# 定义数据库路径
db_path = 'patient_data.db'

# 定义自编码器模型
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(5, 16, kernel_size=3, stride=2, padding=1),  # 输入5个通道（5张切片）
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=1),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
            nn.ReLU()
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            nn.ConvTranspose2d(16, 5, kernel_size=3, stride=2, padding=1, output_padding=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        # 使用 interpolate 将输出调整到 (5, 50, 50)
        decoded = nn.functional.interpolate(decoded, size=(50, 50), mode="bilinear", align_corners=False)
        return encoded, decoded

# 定义数据集类
class NiiDataset(Dataset):
    def __init__(self, nii_files):
        self.nii_files = nii_files

    def __len__(self):
        return len(self.nii_files)

    def __getitem__(self, idx):
        # 加载 .nii 文件并均匀提取 5 张切片
        nii_file = self.nii_files[idx]
        img = sitk.ReadImage(nii_file)
        data = sitk.GetArrayFromImage(img)  # 转换为 NumPy 数组 (depth, height, width)
        
        num_slices = data.shape[0]
        indices = np.linspace(0, num_slices - 1, 5, dtype=int)  # 均匀选择 5 张切片
        slices = data[indices, :, :]  # 提取切片

        # 将每张切片缩放到 50x50 并归一化
        slices_resized = []
        for slice_img in slices:
            slice_img_resized = interpolate(
                torch.tensor(slice_img).unsqueeze(0).unsqueeze(0).float(), 
                size=(50, 50), 
                mode='bilinear', 
                align_corners=False
            ).squeeze(0).squeeze(0)
            slices_resized.append(slice_img_resized)
        
        slices_resized = torch.stack(slices_resized)  # 组合为 (5, 50, 50)
        return slices_resized

# 从数据库提取 .nii 文件路径
def load_nii_files_from_db(db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute("SELECT nii_path FROM patient_data")
    records = cursor.fetchall()
    conn.close()
    nii_files = [record[0] for record in records if os.path.exists(record[0])]
    return nii_files

# 训练自编码器，带有进度显示
def train_autoencoder(dataloader, model, epochs=10, learning_rate=1e-3):
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    model.train()
    for epoch in range(epochs):
        running_loss = 0.0
        progress_bar = tqdm(dataloader, desc=f"Epoch [{epoch+1}/{epochs}]", unit="batch")
        
        for data in progress_bar:
            # 将数据传输到 GPU
            data = data.to(device)
            
            optimizer.zero_grad()
            inputs = data
            _, outputs = model(inputs)
            loss = criterion(outputs, inputs)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            progress_bar.set_postfix({"Loss": loss.item()})
        
        avg_loss = running_loss / len(dataloader)
        print(f"Epoch [{epoch+1}/{epochs}] Average Loss: {avg_loss:.4f}")

# 聚类和分类
def cluster_features(dataloader, model):
    model.eval()
    features = []
    with torch.no_grad():
        for data in dataloader:
            data = data.to(device)  # 将数据传输到 GPU
            encoded, _ = model(data)
            features.append(encoded.view(encoded.size(0), -1))  # 展平特征
    features = torch.cat(features).cpu().numpy()  # 将特征转为 NumPy 数组

    # 使用 K-means 聚类
    kmeans = KMeans(n_clusters=2, random_state=0)
    labels = kmeans.fit_predict(features)
    return labels

# 主流程
nii_files = load_nii_files_from_db(db_path)
dataset = NiiDataset(nii_files)
dataloader = DataLoader(dataset, batch_size=1, shuffle=True)

# 初始化并训练模型

autoencoder = Autoencoder().to(device)
train_autoencoder(dataloader, autoencoder, epochs=10, learning_rate=1e-3)

# 聚类并输出分类结果
labels = cluster_features(dataloader, autoencoder)
for i, label in enumerate(labels):
    print(f"{nii_files[i]} -> 类别: {label}")
# Out:
# Using device: cuda
# Epoch [1/10]:   0%|          | 0/3350 [00:00<?, ?batch/s, Loss=4.57e+5]
# Epoch [1/10]:   1%|▏         | 42/3350 [00:06<08:22,  6.58batch/s, Loss=3.74e+5]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <cell line: 142>()
#     139 # 初始化并训练模型
#     141 autoencoder = Autoencoder().to(device)
# --> 142 train_autoencoder(dataloader, autoencoder, epochs=10, learning_rate=1e-3)
#     144 # 聚类并输出分类结果
#     145 labels = cluster_features(dataloader, autoencoder)
#
# Input In [19], in train_autoencoder(dataloader, model, epochs, learning_rate)
#      98 running_loss = 0.0
#      99 progress_bar = tqdm(dataloader, desc=f"Epoch [{epoch+1}/{epochs}]", unit="batch")
# --> 101 for data in progress_bar:
#     102     # 将数据传输到 GPU
#     103     data = data.to(device)
#     105     optimizer.zero_grad()
#
# File ~/anaconda3/envs/andrew_schant/lib/python3.9/site-packages/tqdm/std.py:1195, in tqdm.__iter__(self)
#    1192 time = self._time
#    1194 try:
# -> 1195     for obj in iterable:
#    1196         yield obj
#    1197         # Update and possibly print the progressbar.
#    1198         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/anaconda3/envs/andrew_schant/lib/python3.9/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/anaconda3/envs/andrew_schant/lib/python3.9/site-packages/torch/utils/data/dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/andrew_schant/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/anaconda3/envs/andrew_schant/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# Input In [19], in NiiDataset.__getitem__(self, idx)
#      60 nii_file = self.nii_files[idx]
#      61 img = sitk.ReadImage(nii_file)
# ---> 62 data = sitk.GetArrayFromImage(img)  # 转换为 NumPy 数组 (depth, height, width)
#      64 num_slices = data.shape[0]
#      65 indices = np.linspace(0, num_slices - 1, 5, dtype=int)  # 均匀选择 5 张切片
#
# File ~/anaconda3/envs/andrew_schant/lib/python3.9/site-packages/SimpleITK/extra.py:290, in GetArrayFromImage(image)
#     287 array_view = GetArrayViewFromImage(image)
#     289 # perform deep copy of the image buffer
# --> 290 return numpy.array(array_view, copy=True)
#
# KeyboardInterrupt:

# %%
import os
import sqlite3
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import SimpleITK as sitk
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# 从数据库中加载 .nii 文件路径
def load_nii_paths_from_db(db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute("SELECT nii_path FROM patient_data")
    records = cursor.fetchall()
    conn.close()
    
    # 提取有效文件路径
    nii_files = [record[0] for record in records if os.path.exists(record[0])]
    return nii_files

# 定义数据集类，用于加载和预处理 .nii 数据
class NiiDataset(Dataset):
    def __init__(self, nii_files, target_shape=(50, 50), num_slices=5):
        self.nii_files = nii_files
        self.target_shape = target_shape
        self.num_slices = num_slices

    def __len__(self):
        return len(self.nii_files)

    def __getitem__(self, idx):
        nii_file = self.nii_files[idx]
        img = sitk.ReadImage(nii_file)
        img_array = sitk.GetArrayFromImage(img)  # (depth, height, width)
        
        # 均匀提取 num_slices 张切片并缩放至 target_shape
        num_total_slices = img_array.shape[0]
        indices = np.linspace(0, num_total_slices - 1, self.num_slices, dtype=int)
        slices = img_array[indices]
        
        # 添加 defaultPixelValue 参数
        slices_resized = [
            np.array(sitk.GetArrayFromImage(
                sitk.Resample(
                    sitk.GetImageFromArray(slice_img),
                    sitk.Transform(),
                    sitk.sitkLinear,
                    defaultPixelValue=0.0,
                    outputPixelType=sitk.sitkFloat32,
                    size=self.target_shape
                )
            )) for slice_img in slices
        ]
        
        # 归一化
        slices_resized = np.stack(slices_resized).astype('float32')
        slices_resized = (slices_resized - np.min(slices_resized)) / (np.max(slices_resized) - np.min(slices_resized))
        
        # 将切片展平为一维向量
        return torch.tensor(slices_resized.flatten(), dtype=torch.float32)


# 定义 VAE 模型
class VAE(nn.Module):
    def __init__(self, original_dim, hidden_dim, latent_dim):
        super(VAE, self).__init__()
        self.fc1 = nn.Linear(original_dim, hidden_dim)
        self.fc2_mean = nn.Linear(hidden_dim, latent_dim)
        self.fc2_logvar = nn.Linear(hidden_dim, latent_dim)
        self.fc3 = nn.Linear(latent_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, original_dim)

    def encode(self, x):
        h1 = torch.relu(self.fc1(x))
        return self.fc2_mean(h1), self.fc2_logvar(h1)

    def reparameterize(self, mean, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mean + eps * std

    def decode(self, z):
        h3 = torch.relu(self.fc3(z))
        return torch.sigmoid(self.fc4(h3))

    def forward(self, x):
        mean, logvar = self.encode(x)
        z = self.reparameterize(mean, logvar)
        return self.decode(z), mean, logvar

# VAE 损失函数
def vae_loss(recon_x, x, mean, logvar):
    reconstruction_loss = nn.functional.binary_cross_entropy(recon_x, x, reduction='sum')
    kl_divergence = -0.5 * torch.sum(1 + logvar - mean.pow(2) - logvar.exp())
    return reconstruction_loss + kl_divergence

# 主流程
db_path = "patient_data.db"
nii_files = load_nii_paths_from_db(db_path)
dataset = NiiDataset(nii_files)
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# 设置设备
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 初始化模型和优化器
original_dim = 50 * 50 * 5
hidden_dim = 128
latent_dim = 2
model = VAE(original_dim, hidden_dim, latent_dim).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# 训练 VAE
epochs = 50
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for batch in dataloader:
        batch = batch.to(device)
        optimizer.zero_grad()
        recon_batch, mean, logvar = model(batch)
        loss = vae_loss(recon_batch, batch, mean, logvar)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    print(f"Epoch {epoch + 1}/{epochs}, Loss: {total_loss / len(dataloader.dataset):.4f}")

# 提取潜在空间表示
model.eval()
with torch.no_grad():
    latents = []
    for batch in dataloader:
        batch = batch.to(device)
        mean, logvar = model.encode(batch)
        latents.append(mean.cpu().numpy())
    latents = np.concatenate(latents)

# 可视化潜在空间
plt.figure(figsize=(8, 6))
plt.scatter(latents[:, 0], latents[:, 1])
plt.colorbar()
plt.xlabel("Latent Dimension 1")
plt.ylabel("Latent Dimension 2")
plt.title("Latent Space Representation")
plt.show()
# Out:
# /tmp/ipykernel_781988/639494072.py:60: RuntimeWarning: invalid value encountered in true_divide
#   slices_resized = (slices_resized - np.min(slices_resized)) / (np.max(slices_resized) - np.min(slices_resized))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [25], in <cell line: 118>()
#     123 optimizer.zero_grad()
#     124 recon_batch, mean, logvar = model(batch)
# --> 125 loss = vae_loss(recon_batch, batch, mean, logvar)
#     126 loss.backward()
#     127 optimizer.step()
#
# Input In [25], in vae_loss(recon_x, x, mean, logvar)
#      95 def vae_loss(recon_x, x, mean, logvar):
#      96     reconstruction_loss = nn.functional.binary_cross_entropy(recon_x, x, reduction='sum')
# ---> 97     kl_divergence = -0.5 * torch.sum(1 + logvar - mean.pow(2) - logvar.exp())
#      98     return reconstruction_loss + kl_divergence
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
import os
import numpy as np
import SimpleITK as sitk
import sqlite3
from skimage.metrics import structural_similarity as ssim
from concurrent.futures import ThreadPoolExecutor
import cv2

# 从数据库中加载 .nii 文件路径
def load_nii_paths_from_db(db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute("SELECT nii_path FROM patient_data")
    records = cursor.fetchall()
    conn.close()
    
    nii_files = [record[0] for record in records if os.path.exists(record[0])]
    return nii_files

# 添加 similarity 列
def add_similarity_column(db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute("PRAGMA table_info(patient_data)")
    columns = [column[1] for column in cursor.fetchall()]
    if 'similarity' not in columns:
        cursor.execute("ALTER TABLE patient_data ADD COLUMN similarity REAL")
    conn.commit()
    conn.close()

# 加载基准切片
def load_reference_slice(reference_path, slice_index=43, target_shape=(100, 100)):
    reference_img = sitk.ReadImage(reference_path)
    reference_data = sitk.GetArrayFromImage(reference_img)
    
    # 获取指定的切片，并调整大小
    reference_slice = reference_data[slice_index]
    reference_resized = cv2.resize(reference_slice, target_shape, interpolation=cv2.INTER_LINEAR)
    return reference_resized

# 计算与基准切片的最大相似度
def calculate_max_similarity_with_reference(nii_path, reference_slice, target_shape=(100, 100), num_slices=10):
    img = sitk.ReadImage(nii_path)
    img_data = sitk.GetArrayFromImage(img)
    num_slices_total = img_data.shape[0]
    
    # 均匀提取 num_slices 张切片并调整大小
    indices = np.linspace(0, num_slices_total - 1, num_slices, dtype=int)
    img_slices = img_data[indices]
    img_resized_slices = [
        cv2.resize(slice_img, target_shape, interpolation=cv2.INTER_LINEAR)
        for slice_img in img_slices
    ]
    
    # 计算每张切片与基准切片的 SSIM，取最大值
    ssim_values = [
        ssim(img_slice, reference_slice, data_range=img_slice.max() - img_slice.min())
        for img_slice in img_resized_slices
    ]
    return max(ssim_values)

# 写入数据库
def write_similarity_to_db(db_path, nii_path, similarity):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute("UPDATE patient_data SET similarity = ? WHERE nii_path = ?", (similarity, nii_path))
    conn.commit()
    conn.close()

# 并行任务
def process_file(nii_path):
    similarity = calculate_max_similarity_with_reference(nii_path, reference_slice, target_shape=target_shape, num_slices=num_slices)
    write_similarity_to_db(db_path, nii_path, similarity)
    print(f"{nii_path} 的相似性为: {similarity:.4f}")

# 主流程
db_path = "patient_data.db"
reference_path = "/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19074/23.nii"
slice_index = 43
target_shape = (100, 100)
num_slices = 10

# 添加数据库列
add_similarity_column(db_path)

# 加载基准文件的指定切片
reference_slice = load_reference_slice(reference_path, slice_index=slice_index, target_shape=target_shape)

# 加载数据库中的 .nii 文件路径
nii_files = load_nii_paths_from_db(db_path)

# 使用 ThreadPoolExecutor 并行处理
with ThreadPoolExecutor(max_workers=32) as executor:
    executor.map(process_file, nii_files)

print("所有相似性数据已写入数据库。")
# Out:
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/3.nii 的相似性为: 0.1271
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18437/4.nii 的相似性为: 0.0714
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/11.nii 的相似性为: 0.0618
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/6.nii 的相似性为: 0.0688
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/12.nii 的相似性为: 0.0675
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33494/6.nii 的相似性为: 0.1322
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18437/3.nii 的相似性为: 0.0553
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/5.nii 的相似性为: 0.1112
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/5.nii 的相似性为: 0.0700
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/4.nii 的相似性为: 0.0760
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/2.nii 的相似性为: 0.0283
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18437/2.nii 的相似性为: 0.0457
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/14.nii 的相似性为: 0.1321
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/4.nii 的相似性为: 0.0673
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/0.nii 的相似性为: 0.1321
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33494/3.nii 的相似性为: 0.1447
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18437/0.nii 的相似性为: 0.0757
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/9.nii 的相似性为: 0.0734
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/3.nii 的相似性为: 0.0660
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/2.nii 的相似性为: 0.0688
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/13.nii 的相似性为: 0.0717
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33494/5.nii 的相似性为: 0.1249
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/1.nii 的相似性为: 0.0233
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18437/1.nii 的相似性为: 0.0937
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33494/0.nii 的相似性为: 0.1036
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33494/2.nii 的相似性为: 0.1481
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/10.nii 的相似性为: 0.0698
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34206/0.nii 的相似性为: 0.1330
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33494/4.nii 的相似性为: 0.0455
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/7.nii 的相似性为: 0.0699
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/6.nii 的相似性为: 0.0686
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/1.nii 的相似性为: 0.0643
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_50012/0.nii 的相似性为: 0.0547
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7759/8.nii 的相似性为: 0.0717
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33494/1.nii 的相似性为: 0.1501
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/3.nii 的相似性为: 0.1221
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/10.nii 的相似性为: 0.1566
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/2.nii 的相似性为: 0.1298
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/12.nii 的相似性为: 0.1516
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/6.nii 的相似性为: 0.1262
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/3.nii 的相似性为: 0.1031
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/11.nii 的相似性为: 0.1010
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/8.nii 的相似性为: 0.1521
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/13.nii 的相似性为: 0.1298/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/10.nii 的相似性为: 0.1117
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/4.nii 的相似性为: 0.1024
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/5.nii 的相似性为: 0.1289
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/7.nii 的相似性为: 0.1353
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/0.nii 的相似性为: 0.1006
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/6.nii 的相似性为: 0.1019
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/9.nii 的相似性为: 0.1555
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/0.nii 的相似性为: 0.1424
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/11.nii 的相似性为: 0.0720
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/8.nii 的相似性为: 0.1087
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/2.nii 的相似性为: 0.1042
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33548/3.nii 的相似性为: 0.0533
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/9.nii 的相似性为: 0.1080
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/7.nii 的相似性为: 0.1178
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/1.nii 的相似性为: 0.1135
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15951/5.nii 的相似性为: 0.1019
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30478/3.nii 的相似性为: 0.0884
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9045/3.nii 的相似性为: 0.0286
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30478/5.nii 的相似性为: 0.0665
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33548/4.nii 的相似性为: 0.1128
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30478/0.nii 的相似性为: 0.0569
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_50672/0.nii 的相似性为: 0.0762
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_50672/1.nii 的相似性为: 0.0864
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33548/0.nii 的相似性为: 0.0676
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33548/2.nii 的相似性为: 0.0643
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30478/4.nii 的相似性为: 0.0597
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/4.nii 的相似性为: 0.1331
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11446/1.nii 的相似性为: 0.1604
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30478/2.nii 的相似性为: 0.0976
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/0.nii 的相似性为: 0.1301
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/3.nii 的相似性为: 0.1164
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/6.nii 的相似性为: 0.1250
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/7.nii 的相似性为: 0.1140
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/10.nii 的相似性为: 0.1290
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/2.nii 的相似性为: 0.1127
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_50485/0.nii 的相似性为: 0.0693
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/5.nii 的相似性为: 0.0628
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26666/2.nii 的相似性为: 0.1015
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/8.nii 的相似性为: 0.1222
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33151/1.nii 的相似性为: 0.0545
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/4.nii 的相似性为: 0.1205
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/5.nii 的相似性为: 0.1300
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/1.nii 的相似性为: 0.1300
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/3.nii 的相似性为: 0.0733/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26666/3.nii 的相似性为: 0.0250
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33548/1.nii 的相似性为: 0.1077
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/2.nii 的相似性为: 0.0698
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/9.nii 的相似性为: 0.1273
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/0.nii 的相似性为: 0.0778
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/6.nii 的相似性为: 0.0673
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33151/0.nii 的相似性为: 0.0918
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/1.nii 的相似性为: 0.0729
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/7.nii 的相似性为: 0.0770
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/8.nii 的相似性为: 0.0804
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/11.nii 的相似性为: 0.0777
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26538/11.nii 的相似性为: 0.1025
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/4.nii 的相似性为: 0.0646
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/10.nii 的相似性为: 0.0826
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30478/1.nii 的相似性为: 0.0778
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8580/9.nii 的相似性为: 0.0775
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9045/2.nii 的相似性为: 0.0718
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9045/0.nii 的相似性为: 0.1180
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9045/1.nii 的相似性为: 0.0930
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_54431/0.nii 的相似性为: 0.0691
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_52131/0.nii 的相似性为: 0.1076
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_54431/2.nii 的相似性为: 0.1200
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_23547/3.nii 的相似性为: 0.0169
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_23547/6.nii 的相似性为: 0.0300
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_23547/2.nii 的相似性为: 0.0493
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_23547/7.nii 的相似性为: 0.0227
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_23547/8.nii 的相似性为: 0.0000
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_23547/5.nii 的相似性为: -0.0050
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_54431/1.nii 的相似性为: 0.1395
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_23547/4.nii 的相似性为: 0.0058
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53998/0.nii 的相似性为: 0.1547
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53998/3.nii 的相似性为: 0.2265
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/6.nii 的相似性为: 0.1394
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/3.nii 的相似性为: 0.1305
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53998/2.nii 的相似性为: 0.3636
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/10.nii 的相似性为: 0.1277
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/9.nii 的相似性为: 0.1318
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/0.nii 的相似性为: 0.1303
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53998/5.nii 的相似性为: 0.0336
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/1.nii 的相似性为: 0.1381
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/2.nii 的相似性为: 0.1548
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/11.nii 的相似性为: 0.1465
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/5.nii 的相似性为: 0.1154
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/4.nii 的相似性为: 0.1145
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/7.nii 的相似性为: 0.1357
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8532/8.nii 的相似性为: 0.1404
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_23547/0.nii 的相似性为: 0.1250
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/8.nii 的相似性为: 0.1043
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/9.nii 的相似性为: 0.1038
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/10.nii 的相似性为: 0.1059
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26666/1.nii 的相似性为: 0.0577
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/4.nii 的相似性为: 0.0962
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/6.nii 的相似性为: 0.0992
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/2.nii 的相似性为: 0.1045
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/0.nii 的相似性为: 0.1005
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/5.nii 的相似性为: 0.0963
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_23547/1.nii 的相似性为: 0.1263
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/7.nii 的相似性为: 0.1031
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/11.nii 的相似性为: 0.1057
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/3.nii 的相似性为: 0.1034
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26986/1.nii 的相似性为: 0.0627
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26666/0.nii 的相似性为: 0.0555
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53998/1.nii 的相似性为: 0.3537
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53998/4.nii 的相似性为: 0.0117
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_52131/1.nii 的相似性为: 0.1061
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33601/3.nii 的相似性为: 0.0882
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33601/2.nii 的相似性为: 0.0618
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33601/1.nii 的相似性为: 0.0463
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33601/4.nii 的相似性为: 0.0614
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_54431/3.nii 的相似性为: 0.1238
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33601/0.nii 的相似性为: 0.0603
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_50887/0.nii 的相似性为: 0.0713
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18790/3.nii 的相似性为: 0.0403
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18790/4.nii 的相似性为: 0.0403
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18790/0.nii 的相似性为: 0.0501
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20426/0.nii 的相似性为: 0.1354
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/2.nii 的相似性为: 0.1249
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/6.nii 的相似性为: 0.0288
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/2.nii 的相似性为: 0.0380
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18790/1.nii 的相似性为: 0.1139
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/0.nii 的相似性为: 0.1171
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/5.nii 的相似性为: 0.0182
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/9.nii 的相似性为: 0.0417
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20426/2.nii 的相似性为: 0.1111
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18790/2.nii 的相似性为: 0.1225
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/4.nii 的相似性为: 0.0426
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/10.nii 的相似性为: 0.0495
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/3.nii 的相似性为: 0.0626
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/15.nii 的相似性为: 0.0655
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30908/4.nii 的相似性为: 0.0494
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30908/3.nii 的相似性为: 0.0523
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30908/2.nii 的相似性为: 0.0579
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31768/3.nii 的相似性为: 0.0622
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/1.nii 的相似性为: 0.0378
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31768/2.nii 的相似性为: 0.0688
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31768/4.nii 的相似性为: 0.0869
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/3.nii 的相似性为: 0.1246
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/6.nii 的相似性为: 0.1225
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/7.nii 的相似性为: 0.1269
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/7.nii 的相似性为: 0.0479
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/8.nii 的相似性为: 0.0697
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31768/5.nii 的相似性为: 0.0913
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32873/0.nii 的相似性为: 0.0553
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/9.nii 的相似性为: 0.1156
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20426/1.nii 的相似性为: 0.1196
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/5.nii 的相似性为: 0.1235
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/0.nii 的相似性为: 0.1017
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31768/0.nii 的相似性为: 0.1041
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/8.nii 的相似性为: 0.1200
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/1.nii 的相似性为: 0.1155
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32873/5.nii 的相似性为: 0.0365
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32873/6.nii 的相似性为: 0.0948
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32873/7.nii 的相似性为: 0.1281
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/0.nii 的相似性为: 0.1384
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/14.nii 的相似性为: 0.0630
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_856/4.nii 的相似性为: 0.1243
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32873/4.nii 的相似性为: 0.1359
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31768/1.nii 的相似性为: 0.0859
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/12.nii 的相似性为: 0.0852
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32873/1.nii 的相似性为: 0.0681
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30908/0.nii 的相似性为: 0.1034
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/13.nii 的相似性为: 0.0669
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25282/11.nii 的相似性为: 0.0740
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30908/1.nii 的相似性为: 0.0991
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32873/3.nii 的相似性为: 0.2210
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32873/2.nii 的相似性为: 0.0344
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/3.nii 的相似性为: 0.1131
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/2.nii 的相似性为: 0.1222
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/10.nii 的相似性为: 0.1249
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/4.nii 的相似性为: 0.1164
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/12.nii 的相似性为: 0.1192
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/5.nii 的相似性为: 0.1224
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/6.nii 的相似性为: 0.1225
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/11.nii 的相似性为: 0.1278
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30065/3.nii 的相似性为: 0.0886
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/7.nii 的相似性为: 0.1147
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_55421/2.nii 的相似性为: 0.0629/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/1.nii 的相似性为: 0.1380
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/9.nii 的相似性为: 0.1251
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_55421/0.nii 的相似性为: 0.0692
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30065/2.nii 的相似性为: 0.0844
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30065/0.nii 的相似性为: 0.1128
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30065/4.nii 的相似性为: 0.1686
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33854/3.nii 的相似性为: 0.0873
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/0.nii 的相似性为: 0.0802
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33854/0.nii 的相似性为: 0.1302
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33318/3.nii 的相似性为: 0.0376/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33318/2.nii 的相似性为: 0.0441
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_55421/1.nii 的相似性为: 0.0816
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33854/4.nii 的相似性为: 0.0963
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33318/5.nii 的相似性为: 0.0991
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33318/4.nii 的相似性为: 0.0787
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30065/1.nii 的相似性为: 0.1302
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18738/8.nii 的相似性为: 0.1211
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33854/2.nii 的相似性为: 0.0600
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/1.nii 的相似性为: 0.0330
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/0.nii 的相似性为: 0.0741
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33854/1.nii 的相似性为: 0.1002
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33318/0.nii 的相似性为: 0.1100
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33318/1.nii 的相似性为: 0.0451
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/3.nii 的相似性为: 0.1588
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/6.nii 的相似性为: 0.0890
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/0.nii 的相似性为: 0.0817
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/5.nii 的相似性为: 0.1054
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/4.nii 的相似性为: 0.0352
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53976/2.nii 的相似性为: 0.0519
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53976/1.nii 的相似性为: 0.0346
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_52554/0.nii 的相似性为: 0.0815
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_52554/2.nii 的相似性为: 0.0722
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/10.nii 的相似性为: 0.0836
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/3.nii 的相似性为: 0.0682
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/11.nii 的相似性为: 0.0791
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/2.nii 的相似性为: 0.0916
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/1.nii 的相似性为: 0.0816
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/5.nii 的相似性为: 0.0661
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/2.nii 的相似性为: 0.0691/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/12.nii 的相似性为: 0.0932
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/13.nii 的相似性为: 0.0808
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/7.nii 的相似性为: 0.0784
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/9.nii 的相似性为: 0.0892
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/8.nii 的相似性为: 0.0757
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/7.nii 的相似性为: 0.0691
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/4.nii 的相似性为: 0.0631/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/12.nii 的相似性为: 0.0701
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/3.nii 的相似性为: 0.1018
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/9.nii 的相似性为: 0.0841/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_52554/1.nii 的相似性为: 0.1349
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16130/6.nii 的相似性为: 0.0713
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/2.nii 的相似性为: 0.1650
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/6.nii 的相似性为: 0.0791
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/8.nii 的相似性为: 0.0920
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32186/1.nii 的相似性为: 0.1548
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/11.nii 的相似性为: 0.0930
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/3.nii 的相似性为: 0.0831
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/2.nii 的相似性为: 0.0264
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/17.nii 的相似性为: 0.1893
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/5.nii 的相似性为: 0.0836
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/10.nii 的相似性为: 0.0966
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53253/0.nii 的相似性为: 0.0944
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_2652/2.nii 的相似性为: 0.0316
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/1.nii 的相似性为: 0.0773
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14874/4.nii 的相似性为: 0.0848
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_2652/3.nii 的相似性为: 0.0390
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/6.nii 的相似性为: 0.0646
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/12.nii 的相似性为: 0.0381
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/5.nii 的相似性为: 0.0660
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/7.nii 的相似性为: 0.1950
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/12.nii 的相似性为: 0.1826
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/15.nii 的相似性为: 0.1908
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/9.nii 的相似性为: 0.1927
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/10.nii 的相似性为: 0.1932
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/14.nii 的相似性为: 0.1831/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/5.nii 的相似性为: 0.0332
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/9.nii 的相似性为: 0.0651
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/6.nii 的相似性为: 0.2006
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/16.nii 的相似性为: 0.2006
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/8.nii 的相似性为: 0.1915
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34656/5.nii 的相似性为: 0.0831
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/11.nii 的相似性为: 0.1805
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/7.nii 的相似性为: 0.0468
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/13.nii 的相似性为: 0.1720
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34656/4.nii 的相似性为: 0.0724
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/2.nii 的相似性为: 0.0518
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/0.nii 的相似性为: 0.1691
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/10.nii 的相似性为: 0.0432
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/8.nii 的相似性为: 0.0493
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/0.nii 的相似性为: 0.0568
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/13.nii 的相似性为: 0.0592
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/3.nii 的相似性为: 0.0521
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_2652/1.nii 的相似性为: 0.0476
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_2652/0.nii 的相似性为: 0.0663
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/4.nii 的相似性为: 0.0597
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34656/0.nii 的相似性为: 0.0675
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/11.nii 的相似性为: 0.0578
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34790/4.nii 的相似性为: 0.0703
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34656/3.nii 的相似性为: 0.0589
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15252/4.nii 的相似性为: 0.0499
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/16.nii 的相似性为: 0.0573
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_53976/0.nii 的相似性为: 0.1013
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/1.nii 的相似性为: 0.0445
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/18.nii 的相似性为: 0.0546
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_41503/0.nii 的相似性为: 0.0374
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/15.nii 的相似性为: 0.0536
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/17.nii 的相似性为: 0.0534
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34656/2.nii 的相似性为: 0.0674
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34656/1.nii 的相似性为: 0.0674
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25367/14.nii 的相似性为: 0.0493
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30694/3.nii 的相似性为: 0.0816
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30694/6.nii 的相似性为: 0.0728
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30694/7.nii 的相似性为: 0.0890
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30694/5.nii 的相似性为: 0.0727
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30694/4.nii 的相似性为: 0.0694
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15252/9.nii 的相似性为: 0.1292
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/10.nii 的相似性为: 0.1007
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15252/1.nii 的相似性为: 0.1204
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15252/0.nii 的相似性为: 0.0740
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15252/7.nii 的相似性为: 0.1203
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15252/6.nii 的相似性为: 0.1148
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/2.nii 的相似性为: 0.1004
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/7.nii 的相似性为: 0.1032
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15252/2.nii 的相似性为: 0.1185/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/9.nii 的相似性为: 0.0999
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15252/5.nii 的相似性为: 0.1117
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/1.nii 的相似性为: 0.1107
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15252/3.nii 的相似性为: 0.1147
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/6.nii 的相似性为: 0.1052
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/4.nii 的相似性为: 0.0979
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/8.nii 的相似性为: 0.1034
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15252/8.nii 的相似性为: 0.1200
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/0.nii 的相似性为: 0.1094
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/3.nii 的相似性为: 0.0992
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/11.nii 的相似性为: 0.1012
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_54750/0.nii 的相似性为: 0.0623
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9531/5.nii 的相似性为: 0.1033
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_54750/1.nii 的相似性为: 0.0639
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/2.nii 的相似性为: 0.0939
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/0.nii 的相似性为: 0.0774
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/6.nii 的相似性为: 0.0985
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/10.nii 的相似性为: 0.1019
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/3.nii 的相似性为: 0.0930
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/10.nii 的相似性为: 0.0854
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/7.nii 的相似性为: 0.0865
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30967/3.nii 的相似性为: 0.0511
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/1.nii 的相似性为: 0.0938
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/8.nii 的相似性为: 0.0858
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/6.nii 的相似性为: 0.1029
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/4.nii 的相似性为: 0.1083
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30967/2.nii 的相似性为: 0.0715
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30967/5.nii 的相似性为: 0.0410
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/3.nii 的相似性为: 0.1132
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30967/0.nii 的相似性为: 0.0867
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30967/4.nii 的相似性为: 0.0579
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/5.nii 的相似性为: 0.0827
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/0.nii 的相似性为: 0.0874
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/2.nii 的相似性为: 0.1137
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/9.nii 的相似性为: 0.0991
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/5.nii 的相似性为: 0.1082
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/11.nii 的相似性为: 0.1144
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31049/3.nii 的相似性为: 0.0807
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/7.nii 的相似性为: 0.0979
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/1.nii 的相似性为: 0.0777
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/9.nii 的相似性为: 0.0995
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_15755/8.nii 的相似性为: 0.0990
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32641/4.nii 的相似性为: 0.0517
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32641/3.nii 的相似性为: 0.0760
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32641/2.nii 的相似性为: 0.0665
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32641/5.nii 的相似性为: 0.0744
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31049/4.nii 的相似性为: 0.1039
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31049/0.nii 的相似性为: 0.1008
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31049/2.nii 的相似性为: 0.0498
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11748/3.nii 的相似性为: 0.0288
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32641/6.nii 的相似性为: 0.0884
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32641/0.nii 的相似性为: 0.0831
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11748/6.nii 的相似性为: 0.0087
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11748/7.nii 的相似性为: 0.0030
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11748/4.nii 的相似性为: 0.0390
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11748/5.nii 的相似性为: 0.0426
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/11.nii 的相似性为: 0.0752
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11748/2.nii 的相似性为: 0.0205
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31049/1.nii 的相似性为: 0.1091
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/6.nii 的相似性为: 0.0350
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/0.nii 的相似性为: 0.0837
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/12.nii 的相似性为: 0.0364
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32641/1.nii 的相似性为: 0.0898
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30967/1.nii 的相似性为: 0.0567
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10255/4.nii 的相似性为: 0.0841
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_24125/2.nii 的相似性为: 0.1156
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/7.nii 的相似性为: 0.0513
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/10.nii 的相似性为: 0.0427
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9669/0.nii 的相似性为: 0.0868
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/8.nii 的相似性为: 0.0990
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_24125/1.nii 的相似性为: 0.1196
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11748/0.nii 的相似性为: 0.0842
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/15.nii 的相似性为: 0.0899
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/5.nii 的相似性为: 0.0837
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/9.nii 的相似性为: 0.0725
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/11.nii 的相似性为: 0.0689
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/1.nii 的相似性为: 0.0219
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/2.nii 的相似性为: 0.0972
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11748/1.nii 的相似性为: 0.1170
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/3.nii 的相似性为: 0.0890
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/0.nii 的相似性为: 0.0706
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/27.nii 的相似性为: 0.1591
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25071/0.nii 的相似性为: 0.1046
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_24125/0.nii 的相似性为: 0.1279
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/18.nii 的相似性为: 0.1568
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/20.nii 的相似性为: 0.1529
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/22.nii 的相似性为: 0.1433
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32573/3.nii 的相似性为: 0.0744
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/23.nii 的相似性为: 0.1490
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32573/5.nii 的相似性为: 0.0874
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32573/2.nii 的相似性为: 0.0449
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/13.nii 的相似性为: 0.0972
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/24.nii 的相似性为: 0.1525
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20825/0.nii 的相似性为: 0.0781
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32573/4.nii 的相似性为: 0.0802
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32573/0.nii 的相似性为: 0.0468
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20825/5.nii 的相似性为: 0.0394
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20825/9.nii 的相似性为: 0.1027
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20825/1.nii 的相似性为: 0.0805
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/16.nii 的相似性为: 0.1614
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/21.nii 的相似性为: 0.1444
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/14.nii 的相似性为: 0.0890
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/7.nii 的相似性为: 0.0398
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/8.nii 的相似性为: 0.0439
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/4.nii 的相似性为: 0.0899
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/6.nii 的相似性为: 0.0421
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/3.nii 的相似性为: 0.0411
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/2.nii 的相似性为: 0.0395
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/5.nii 的相似性为: 0.0405
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/26.nii 的相似性为: 0.1576
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/10.nii 的相似性为: 0.0392
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/19.nii 的相似性为: 0.1535
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25071/1.nii 的相似性为: 0.1134
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25071/3.nii 的相似性为: 0.1133
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/9.nii 的相似性为: 0.0432
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/1.nii 的相似性为: 0.0401
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25071/2.nii 的相似性为: 0.1086
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/25.nii 的相似性为: 0.1528
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32573/1.nii 的相似性为: 0.0945
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/11.nii 的相似性为: 0.0384
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31261/4.nii 的相似性为: 0.0422
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20825/6.nii 的相似性为: 0.0802
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_24919/3.nii 的相似性为: 0.0439
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_24919/2.nii 的相似性为: 0.0221
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20825/4.nii 的相似性为: 0.0998
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20825/3.nii 的相似性为: 0.0845
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_24919/4.nii 的相似性为: 0.0195
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20825/2.nii 的相似性为: 0.0850
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20825/8.nii 的相似性为: 0.0878
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_24919/0.nii 的相似性为: 0.0503
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_20825/7.nii 的相似性为: 0.0886
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26576/9.nii 的相似性为: 0.1220
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_50212/0.nii 的相似性为: 0.0973
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_50212/2.nii 的相似性为: 0.1063
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_50212/1.nii 的相似性为: 0.0556
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26576/3.nii 的相似性为: 0.0878
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26576/7.nii 的相似性为: 0.1182
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26576/8.nii 的相似性为: 0.1217
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26576/2.nii 的相似性为: 0.0987
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26576/6.nii 的相似性为: 0.1135
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26576/0.nii 的相似性为: 0.0995
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26576/5.nii 的相似性为: 0.1005
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26576/1.nii 的相似性为: 0.1078
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5982/8.nii 的相似性为: 0.0819
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/10.nii 的相似性为: 0.1675
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/0.nii 的相似性为: 0.1760
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/3.nii 的相似性为: 0.1796
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26576/4.nii 的相似性为: 0.1079
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/5.nii 的相似性为: 0.1781
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/11.nii 的相似性为: 0.1577
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/8.nii 的相似性为: 0.1677
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5982/2.nii 的相似性为: 0.0807
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5982/3.nii 的相似性为: 0.0914
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5982/6.nii 的相似性为: 0.1100
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/9.nii 的相似性为: 0.1578
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/1.nii 的相似性为: 0.1529
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/4.nii 的相似性为: 0.1863
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/7.nii 的相似性为: 0.1747
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10687/17.nii 的相似性为: 0.1688
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_24919/1.nii 的相似性为: 0.0771
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/2.nii 的相似性为: 0.1739
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5982/5.nii 的相似性为: 0.1011
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5982/7.nii 的相似性为: 0.0949
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5982/0.nii 的相似性为: 0.0945
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25576/6.nii 的相似性为: 0.1562
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34779/3.nii 的相似性为: 0.0603
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/6.nii 的相似性为: 0.0629
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34779/2.nii 的相似性为: 0.0477
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34779/5.nii 的相似性为: 0.0478
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/3.nii 的相似性为: 0.0913
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18343/0.nii 的相似性为: 0.2054
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_4554/2.nii 的相似性为: 0.1558
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34779/4.nii 的相似性为: 0.0660
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5982/1.nii 的相似性为: 0.0875
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5982/4.nii 的相似性为: 0.1112
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/8.nii 的相似性为: 0.0379
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/2.nii 的相似性为: 0.0680
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/5.nii 的相似性为: 0.0892
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_4554/0.nii 的相似性为: 0.1516
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34779/1.nii 的相似性为: 0.0754
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34779/0.nii 的相似性为: 0.0543
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34634/5.nii 的相似性为: 0.0530
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/4.nii 的相似性为: 0.0717
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34634/3.nii 的相似性为: 0.0471
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_4554/1.nii 的相似性为: 0.1550
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34634/4.nii 的相似性为: 0.0200
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34634/6.nii 的相似性为: 0.0436
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/12.nii 的相似性为: 0.1085
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_35135/0.nii 的相似性为: 0.0340
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_35135/2.nii 的相似性为: 0.0489
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_35135/3.nii 的相似性为: 0.0373
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_35135/4.nii 的相似性为: 0.1204
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_35135/5.nii 的相似性为: 0.0799
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31048/2.nii 的相似性为: 0.0525
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/0.nii 的相似性为: 0.1290
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/7.nii 的相似性为: 0.1379
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31048/3.nii 的相似性为: 0.0641
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31048/4.nii 的相似性为: 0.0734
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31048/5.nii 的相似性为: 0.1245
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34634/1.nii 的相似性为: 0.0370
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31048/0.nii 的相似性为: 0.0935
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/1.nii 的相似性为: 0.1365
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_35135/1.nii 的相似性为: 0.0789
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31048/1.nii 的相似性为: 0.1339
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/10.nii 的相似性为: 0.1023
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5999/0.nii 的相似性为: 0.1184
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5999/1.nii 的相似性为: 0.0703
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5999/2.nii 的相似性为: 0.0705
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34634/0.nii 的相似性为: 0.0429
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5999/3.nii 的相似性为: 0.0739
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5999/5.nii 的相似性为: 0.0782
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34634/2.nii 的相似性为: 0.0299
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5999/4.nii 的相似性为: 0.0747
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/9.nii 的相似性为: 0.0993
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19604/11.nii 的相似性为: 0.0997
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/6.nii 的相似性为: 0.0820
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16352/0.nii 的相似性为: 0.0618
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_54280/0.nii 的相似性为: 0.0773
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/10.nii 的相似性为: 0.0840
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/3.nii 的相似性为: 0.0928
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_54280/1.nii 的相似性为: 0.1115
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/8.nii 的相似性为: 0.0894
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16352/1.nii 的相似性为: 0.0554
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/0.nii 的相似性为: 0.0840
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_41508/0.nii 的相似性为: 0.1617
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/5.nii 的相似性为: 0.0779
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/7.nii 的相似性为: 0.0863
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/2.nii 的相似性为: 0.1057
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30685/6.nii 的相似性为: 0.0688
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30685/5.nii 的相似性为: 0.1112
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_55734/2.nii 的相似性为: 0.0865
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30685/3.nii 的相似性为: 0.1271/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/11.nii 的相似性为: 0.0956
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/1.nii 的相似性为: 0.0787
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30685/4.nii 的相似性为: 0.0673
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/3.nii 的相似性为: 0.0602
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/14.nii 的相似性为: 0.0602
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/9.nii 的相似性为: 0.0840
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30685/2.nii 的相似性为: 0.0283
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25668/4.nii 的相似性为: 0.0807
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16352/4.nii 的相似性为: 0.0391
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_55734/1.nii 的相似性为: 0.0571
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16352/3.nii 的相似性为: 0.1358
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16352/2.nii 的相似性为: 0.1362
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/13.nii 的相似性为: 0.1126
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/5.nii 的相似性为: 0.1300
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/4.nii 的相似性为: 0.1370
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/2.nii 的相似性为: 0.0989
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/10.nii 的相似性为: 0.0956
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/12.nii 的相似性为: 0.1018
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/7.nii 的相似性为: 0.0988
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30685/1.nii 的相似性为: 0.0233
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/6.nii 的相似性为: 0.1349
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30685/0.nii 的相似性为: 0.1330
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/11.nii 的相似性为: 0.0942
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/8.nii 的相似性为: 0.0973
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30233/6.nii 的相似性为: 0.0460
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/9.nii 的相似性为: 0.0974
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30233/0.nii 的相似性为: 0.0351
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30233/3.nii 的相似性为: 0.0512
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30233/1.nii 的相似性为: 0.0610
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30233/4.nii 的相似性为: 0.0612
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30233/5.nii 的相似性为: 0.0387
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32435/6.nii 的相似性为: 0.0337
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32435/5.nii 的相似性为: 0.0905
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32435/4.nii 的相似性为: 0.0472
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32435/3.nii 的相似性为: 0.1380
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32435/1.nii 的相似性为: 0.0619
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/0.nii 的相似性为: 0.1006
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_23495/5.nii 的相似性为: 0.0812
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19522/1.nii 的相似性为: 0.1275
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5322/1.nii 的相似性为: 0.0913
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_55734/0.nii 的相似性为: 0.1058
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14244/3.nii 的相似性为: 0.0519
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_54166/0.nii 的相似性为: 0.0689
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_789/0.nii 的相似性为: 0.1589
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30233/2.nii 的相似性为: 0.0527
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14244/2.nii 的相似性为: 0.0473
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19522/2.nii 的相似性为: 0.0942
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32435/2.nii 的相似性为: 0.0216
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_19522/0.nii 的相似性为: 0.0550
# ...
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32750/3.nii 的相似性为: 0.0685
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32750/2.nii 的相似性为: 0.0759
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_13375/7.nii 的相似性为: 0.1324
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32427/3.nii 的相似性为: 0.0562
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_16390/2.nii 的相似性为: 0.0734
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_52474/0.nii 的相似性为: 0.1284
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10128/0.nii 的相似性为: 0.1368
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_13375/5.nii 的相似性为: 0.1280
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_55680/0.nii 的相似性为: 0.0459
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32427/1.nii 的相似性为: 0.0468
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_54312/0.nii 的相似性为: 0.0828
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31693/0.nii 的相似性为: 0.0484
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32029/6.nii 的相似性为: 0.0862
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32029/5.nii 的相似性为: 0.1047
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32029/7.nii 的相似性为: 0.0820
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34531/4.nii 的相似性为: 0.0545
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34531/3.nii 的相似性为: 0.0823
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32750/4.nii 的相似性为: 0.0582
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34531/1.nii 的相似性为: 0.0841
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32029/4.nii 的相似性为: 0.1168
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32029/3.nii 的相似性为: 0.0274
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10128/3.nii 的相似性为: 0.1166
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9595/0.nii 的相似性为: 0.1244
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32750/1.nii 的相似性为: 0.0707
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_22189/1.nii 的相似性为: 0.0854
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_22189/0.nii 的相似性为: 0.0966
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33730/3.nii 的相似性为: 0.0531
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33730/5.nii 的相似性为: 0.0352
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33730/2.nii 的相似性为: 0.0795
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10128/1.nii 的相似性为: 0.1244
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_10128/2.nii 的相似性为: 0.1239
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26704/0.nii 的相似性为: 0.0737
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33730/4.nii 的相似性为: 0.0482
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/0.nii 的相似性为: 0.0981
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5689/2.nii 的相似性为: 0.1297
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/6.nii 的相似性为: 0.1356
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32029/1.nii 的相似性为: 0.0270
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/3.nii 的相似性为: 0.1214
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5689/3.nii 的相似性为: 0.1236
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26704/4.nii 的相似性为: 0.0373
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5689/1.nii 的相似性为: 0.1255
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34531/0.nii 的相似性为: 0.0763
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32029/2.nii 的相似性为: 0.1268
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32029/0.nii 的相似性为: 0.1174
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26704/3.nii 的相似性为: 0.0386
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/7.nii 的相似性为: 0.1451
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_5689/0.nii 的相似性为: 0.1200
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33730/0.nii 的相似性为: 0.0666
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/10.nii 的相似性为: 0.1427
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/0.nii 的相似性为: 0.0857
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/5.nii 的相似性为: 0.1126
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/9.nii 的相似性为: 0.1429
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/3.nii 的相似性为: 0.0990
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/4.nii 的相似性为: 0.1192
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/2.nii 的相似性为: 0.1399
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/1.nii 的相似性为: 0.0742
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34271/3.nii 的相似性为: 0.0578
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34271/0.nii 的相似性为: 0.0587
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34271/5.nii 的相似性为: 0.0872
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/8.nii 的相似性为: 0.1461
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_33730/1.nii 的相似性为: 0.0455
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_55515/0.nii 的相似性为: 0.1002
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_14939/11.nii 的相似性为: 0.1460
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34271/2.nii 的相似性为: 0.1089
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_32750/0.nii 的相似性为: 0.0648
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34271/4.nii 的相似性为: 0.1016
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/12.nii 的相似性为: 0.0967
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/6.nii 的相似性为: 0.1104
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/7.nii 的相似性为: 0.1161
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/5.nii 的相似性为: 0.1199
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/8.nii 的相似性为: 0.1171
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/10.nii 的相似性为: 0.1088
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/9.nii 的相似性为: 0.1140
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26704/1.nii 的相似性为: 0.1628
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26704/2.nii 的相似性为: 0.1618
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/11.nii 的相似性为: 0.1126
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/4.nii 的相似性为: 0.1083
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/2.nii 的相似性为: 0.1226
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34271/1.nii 的相似性为: 0.0860
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_25507/1.nii 的相似性为: 0.1319
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/0.nii 的相似性为: 0.1115
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/10.nii 的相似性为: 0.0630
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/2.nii 的相似性为: 0.0651
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/10.nii 的相似性为: 0.1051/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/6.nii 的相似性为: 0.1039
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/3.nii 的相似性为: 0.0953
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/3.nii 的相似性为: 0.0647
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/9.nii 的相似性为: 0.1053
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34671/3.nii 的相似性为: 0.0440
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/5.nii 的相似性为: 0.0892
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/1.nii 的相似性为: 0.1010
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/8.nii 的相似性为: 0.1034
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/4.nii 的相似性为: 0.0968
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/11.nii 的相似性为: 0.0863
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/8.nii 的相似性为: 0.0586
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/10.nii 的相似性为: 0.0620
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/0.nii 的相似性为: 0.0646
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/0.nii 的相似性为: 0.0585
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/6.nii 的相似性为: 0.0670
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/1.nii 的相似性为: 0.0695
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34671/6.nii 的相似性为: 0.0158
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/8.nii 的相似性为: 0.0697
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/3.nii 的相似性为: 0.0678
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/2.nii 的相似性为: 0.0664
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/1.nii 的相似性为: 0.0660
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/9.nii 的相似性为: 0.0604
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/7.nii 的相似性为: 0.0665
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/5.nii 的相似性为: 0.0691
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/6.nii 的相似性为: 0.0670
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/11.nii 的相似性为: 0.0631
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34671/5.nii 的相似性为: 0.0475
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/2.nii 的相似性为: 0.0933
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/9.nii 的相似性为: 0.0628
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/7.nii 的相似性为: 0.0641
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34671/4.nii 的相似性为: 0.0463
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7240/3.nii 的相似性为: 0.0560
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/4.nii 的相似性为: 0.0760
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7240/2.nii 的相似性为: 0.0703
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7240/0.nii 的相似性为: 0.0327
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34671/1.nii 的相似性为: 0.0522
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_8071/5.nii 的相似性为: 0.0919
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/11.nii 的相似性为: 0.0572
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7240/5.nii 的相似性为: 0.0018
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34491/4.nii 的相似性为: 0.0526
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34491/5.nii 的相似性为: 0.0557
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34491/2.nii 的相似性为: 0.0717
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7240/4.nii 的相似性为: 0.0577
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34491/3.nii 的相似性为: 0.0525
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18722/4.nii 的相似性为: 0.0659
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34491/0.nii 的相似性为: 0.1172
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/0.nii 的相似性为: 0.1110
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_51505/1.nii 的相似性为: 0.0701
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34671/0.nii 的相似性为: 0.0425
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26267/7.nii 的相似性为: 0.0917
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34671/2.nii 的相似性为: 0.0331
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7240/1.nii 的相似性为: 0.1016
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30582/0.nii 的相似性为: 0.1451
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_34491/1.nii 的相似性为: 0.0706
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9646/0.nii 的相似性为: 0.1238
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/6.nii 的相似性为: 0.1303
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9646/2.nii 的相似性为: 0.0642
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/9.nii 的相似性为: 0.1411/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/10.nii 的相似性为: 0.1330
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/2.nii 的相似性为: 0.1315
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/12.nii 的相似性为: 0.1352
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/1.nii 的相似性为: 0.1351
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/8.nii 的相似性为: 0.1408
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/5.nii 的相似性为: 0.1373
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/3.nii 的相似性为: 0.1428
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/11.nii 的相似性为: 0.1336
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/4.nii 的相似性为: 0.1368
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_51505/0.nii 的相似性为: 0.0910
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_21434/7.nii 的相似性为: 0.1373
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_52274/0.nii 的相似性为: 0.0823
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26878/1.nii 的相似性为: 0.1247
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_30582/1.nii 的相似性为: 0.1569
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9646/5.nii 的相似性为: 0.0402
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9646/3.nii 的相似性为: 0.1408
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_52163/0.nii 的相似性为: 0.0670
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9646/4.nii 的相似性为: 0.0420
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_26878/0.nii 的相似性为: 0.1421
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11915/0.nii 的相似性为: 0.0373
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/3.nii 的相似性为: 0.1008
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/0.nii 的相似性为: 0.1097
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31218/0.nii 的相似性为: 0.0558
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/6.nii 的相似性为: 0.1001
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31218/3.nii 的相似性为: 0.0418
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31218/2.nii 的相似性为: 0.0551
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/2.nii 的相似性为: 0.1027
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/7.nii 的相似性为: 0.1034
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31218/4.nii 的相似性为: 0.0625
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31218/5.nii 的相似性为: 0.0763
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_6468/3.nii 的相似性为: 0.0448
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/10.nii 的相似性为: 0.1125
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_6468/2.nii 的相似性为: 0.0156
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/5.nii 的相似性为: 0.0957
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_6468/4.nii 的相似性为: 0.0399
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/8.nii 的相似性为: 0.1063
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/11.nii 的相似性为: 0.1085
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_6468/0.nii 的相似性为: 0.0521
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/3.nii 的相似性为: 0.1470
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11915/3.nii 的相似性为: 0.1158
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_18735/0.nii 的相似性为: 0.1519
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/6.nii 的相似性为: 0.0756
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_6468/6.nii 的相似性为: 0.0559
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_6468/5.nii 的相似性为: 0.0795
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11915/1.nii 的相似性为: 0.1074
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/9.nii 的相似性为: 0.1636
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/9.nii 的相似性为: 0.1066
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/4.nii 的相似性为: 0.0982
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/10.nii 的相似性为: 0.1658
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/8.nii 的相似性为: 0.1643
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/5.nii 的相似性为: 0.0635
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/0.nii 的相似性为: 0.1386/home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/11.nii 的相似性为: 0.1577
#
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_11915/2.nii 的相似性为: 0.1055
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/7.nii 的相似性为: 0.1703
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/4.nii 的相似性为: 0.0547
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_967/1.nii 的相似性为: 0.0996
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/3.nii 的相似性为: 0.1620
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/6.nii 的相似性为: 0.1581
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31218/1.nii 的相似性为: 0.0683
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/2.nii 的相似性为: 0.0492
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/4.nii 的相似性为: 0.1551
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/5.nii 的相似性为: 0.1509
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/0.nii 的相似性为: 0.1463
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/1.nii 的相似性为: 0.1383
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_7136/2.nii 的相似性为: 0.1590
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_9646/1.nii 的相似性为: 0.0977
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_31222/1.nii 的相似性为: 0.0420
# /home/molloi-lab-linux2/Desktop/ZQY/shant/Confirm_50126/0.nii 的相似性为: 0.0898
# 所有相似性数据已写入数据库。

# %%
import os
import numpy as np
import SimpleITK as sitk
import sqlite3
import matplotlib.pyplot as plt

# 从数据库中按相似度从高到低提取 .nii 文件路径
def load_sorted_nii_paths(db_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    cursor.execute("SELECT nii_path, similarity FROM patient_data ORDER BY similarity DESC")
    records = cursor.fetchall()
    conn.close()
    return records  # 返回 [(路径, 相似度), ...]

# 加载 .nii 文件的一个均匀抽样的切片，保持原始分辨率
def load_sample_slice(nii_path, num_slices=10):
    img = sitk.ReadImage(nii_path)
    img_data = sitk.GetArrayFromImage(img)
    num_slices_total = img_data.shape[0]
    
    # 均匀提取 num_slices 张切片中的一张
    slice_index = num_slices_total // 2  # 选取中间切片
    sample_slice = img_data[slice_index]
    return sample_slice

# 展示相似度排序后的切片图像
def display_slices(sorted_records, num_samples=10):
    fig, axes = plt.subplots(1, num_samples, figsize=(20, 5))
    
    for i, (nii_path, similarity) in enumerate(sorted_records[:num_samples]):
        sample_slice = load_sample_slice(nii_path)
        
        # 显示切片
        ax = axes[i]
        ax.imshow(sample_slice, cmap="gray")
        ax.set_title(f"Similarity: {similarity:.4f}")
        ax.axis("off")
    
    plt.tight_layout()
    plt.show()

# 主流程
db_path = "patient_data.db"
num_samples = 10  # 展示前 10 个相似度最高的切片

# 获取按相似度排序的 .nii 文件路径
sorted_records = load_sorted_nii_paths(db_path)

# 展示切片
display_slices(sorted_records, num_samples=num_samples)

# %% [markdown]
# # Validation

# %% [markdown]
# # Handle Data
